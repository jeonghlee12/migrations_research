# %%
import twint
import numpy as np
import pickle
import pandas as pd
import time
import math
from collections import Counter
from datetime import datetime, timedelta
import matplotlib.pyplot as plt

print(pd.__version__)
# Out:
# 1.2.3

# %%
def changeTimezone(df):
    df["times"] = df["date"] + df["timezone"]
    df["times"] = pd.to_datetime(df["times"], format="%Y-%m-%d %H:%M:%S%z", utc=True)
    df["times"] = df["times"].dt.tz_convert("Europe/Madrid")
    
    df["weekday"] = df["times"].dt.dayofweek
    
    return df

def getStats(df):
    stats = dict()
    sample_size = len(df)
    
    stats["size"] = sample_size
    
    if (sample_size == 0):
        return stats
    
    df = changeTimezone(df)
    lang_counts = Counter(df["language"])
    lang_counts =  dict(sorted(lang_counts.items(), reverse=True, key=lambda item: item[1]))
    for k,v in lang_counts.items():
        proportion = v / sample_size
        raw_and_proportion = str(v) + " " + str(proportion)
        lang_counts[k] = raw_and_proportion
    stats["language"] = dict(lang_counts)
    
    days_counts = Counter(df["weekday"])
    days = dict()
    days["weekends"] = days_counts[5] + days_counts[6]
    days["weekdays"] = days_counts[0] + days_counts[1] + days_counts[2] + days_counts[3] + days_counts[4]
    
    total_days = (int(days["weekends"]) + int(days["weekdays"]))
    for k,v in days.items():
        proportion = v / total_days
        raw_and_proportion = str(v) + " " + str(proportion)
        days[k] = raw_and_proportion
    stats["days"] = days
    
    return stats

# %% [markdown]
# ## Foreign data

# %%
# read data
foreign_tweets_by_location = pickle.load( open( "foreign_freq_tweets.p", "rb" ) )

# %%
for k,v in foreign_tweets_by_location.items():
    print(k)
    if (len(set(v["username"])) != 0):
        print("frequency:", len(v), "/ user count:", len(set(v["username"])), "/ freq per user:",len(v) / len(set(v["username"])))
    df_modified = getStats(v)
    for k1, v1 in df_modified.items():
        print(k1)
        if (type(v1) == type(dict())):
            for k2, v2 in v1.items():
                print(k2, v2)
        else: print(v1)
        print()
    print("-----------------------------")
# Out:
# Santa Coloma de Gramanet
# frequency: 599 / user count: 137 / freq per user: 4.372262773722627
# size
# 599
#
# language
# en 159 0.2654424040066778
# ja 134 0.22370617696160267
# pt 58 0.09682804674457429
# ca 50 0.08347245409015025
# es 48 0.08013355592654424
# pl 24 0.04006677796327212
# ro 23 0.038397328881469114
# it 17 0.028380634390651086
# fr 17 0.028380634390651086
# und 15 0.025041736227045076
# in 13 0.021702838063439065
# fi 10 0.01669449081803005
# tr 9 0.015025041736227046
# et 5 0.008347245409015025
# sv 5 0.008347245409015025
# no 2 0.00333889816360601
# sl 2 0.00333889816360601
# vi 2 0.00333889816360601
# da 2 0.00333889816360601
# lv 1 0.001669449081803005
# de 1 0.001669449081803005
# tl 1 0.001669449081803005
# hu 1 0.001669449081803005
#
# days
# weekends 137 0.2287145242070117
# weekdays 462 0.7712854757929883
#
# -----------------------------
# Fluvial del Besos
# frequency: 16 / user count: 6 / freq per user: 2.6666666666666665
# size
# 16
#
# language
# es 16 1.0
#
# days
# weekends 4 0.25
# weekdays 12 0.75
#
# -----------------------------
# Parque Molinet
# frequency: 113 / user count: 42 / freq per user: 2.6904761904761907
# size
# 113
#
# language
# it 67 0.5929203539823009
# en 39 0.34513274336283184
# und 3 0.02654867256637168
# in 1 0.008849557522123894
# ca 1 0.008849557522123894
# fi 1 0.008849557522123894
# es 1 0.008849557522123894
#
# days
# weekends 28 0.24778761061946902
# weekdays 85 0.7522123893805309
#
# -----------------------------
# Plaza del Rellotge
# frequency: 2 / user count: 1 / freq per user: 2.0
# size
# 2
#
# language
# ca 2 1.0
#
# days
# weekends 0 0.0
# weekdays 2 1.0
#
# -----------------------------
# Rambla San Sebastian
# size
# 0
#
# -----------------------------
# Parque Can Zam
# frequency: 32 / user count: 7 / freq per user: 4.571428571428571
# size
# 32
#
# language
# en 22 0.6875
# ca 4 0.125
# es 2 0.0625
# tr 2 0.0625
# fi 1 0.03125
# ro 1 0.03125
#
# days
# weekends 9 0.28125
# weekdays 23 0.71875
#
# -----------------------------
# Instituto Can Peixauet
# frequency: 3 / user count: 2 / freq per user: 1.5
# size
# 3
#
# language
# es 1 0.3333333333333333
# ca 1 0.3333333333333333
# pt 1 0.3333333333333333
#
# days
# weekends 0 0.0
# weekdays 3 1.0
#
# -----------------------------
# Parque Gran Sol
# frequency: 44 / user count: 37 / freq per user: 1.1891891891891893
# size
# 44
#
# language
# en 16 0.36363636363636365
# es 14 0.3181818181818182
# it 10 0.22727272727272727
# pt 1 0.022727272727272728
# ca 1 0.022727272727272728
# ja 1 0.022727272727272728
# fr 1 0.022727272727272728
#
# days
# weekends 20 0.45454545454545453
# weekdays 24 0.5454545454545454
#
# -----------------------------
# Escuela Tanit
# size
# 0
#
# -----------------------------
# Instituto Terra Roja
# frequency: 1 / user count: 1 / freq per user: 1.0
# size
# 1
#
# language
# en 1 1.0
#
# days
# weekends 0 0.0
# weekdays 1 1.0
#
# -----------------------------
# Instituto Gassol
# size
# 0
#
# -----------------------------
# CAP Santa Rosa
# size
# 0
#
# -----------------------------
# Cinto Verdaguer
# frequency: 1 / user count: 1 / freq per user: 1.0
# size
# 1
#
# language
# pt 1 1.0
#
# days
# weekends 0 0.0
# weekdays 1 1.0
#
# -----------------------------
# Mercado del Fondo
# frequency: 1798 / user count: 592 / freq per user: 3.0371621621621623
# size
# 1798
#
# language
# it 1735 0.9649610678531702
# es 31 0.017241379310344827
# pt 9 0.005005561735261402
# en 9 0.005005561735261402
# ht 4 0.002224694104560623
# ja 4 0.002224694104560623
# ca 2 0.0011123470522803114
# cy 1 0.0005561735261401557
# in 1 0.0005561735261401557
# nl 1 0.0005561735261401557
# tr 1 0.0005561735261401557
#
# days
# weekends 264 0.1468298109010011
# weekdays 1534 0.8531701890989989
#
# -----------------------------
# Nus de la Trinitat
# size
# 0
#
# -----------------------------
# Macanet str
# size
# 0
#
# -----------------------------
# Iglesia Evangelica
# size
# 0
#
# -----------------------------

# %% [markdown]
# ## Native data

# %%
n1 = pickle.load(open("native_freq_tweets1.p", "rb"))
n2 = pickle.load(open("native_freq_tweets2.p", "rb"))
n3 = pickle.load(open("native_freq_tweets3.p", "rb"))
n4 = pickle.load(open("native_freq_tweets4.p", "rb"))
n5 = pickle.load(open("native_freq_tweets5.p", "rb"))
n6 = pickle.load(open("native_freq_tweets6.p", "rb"))
n7 = pickle.load(open("native_freq_tweets7.p", "rb"))
n8 = pickle.load(open("native_freq_tweets8.p", "rb"))
n9 = pickle.load(open("native_freq_tweets9.p", "rb"))
n10 = pickle.load(open("native_freq_tweets10.p", "rb"))
n11 = pickle.load(open("native_freq_tweets11.p", "rb"))
n12 = pickle.load(open("native_freq_tweets12.p", "rb"))
n13 = pickle.load(open("native_freq_tweets13.p", "rb"))
n14 = pickle.load(open("native_freq_tweets14.p", "rb"))
n15 = pickle.load(open("native_freq_tweets15.p", "rb"))
n16 = pickle.load(open("native_freq_tweets16.p", "rb"))
n17 = pickle.load(open("native_freq_tweets17.p", "rb"))
n18 = pickle.load(open("native_freq_tweets18.p", "rb"))
n18_5 = pickle.load(open("native_freq_tweets18_5.p", "rb"))
n19 = pickle.load(open("native_freq_tweets19.p", "rb"))
n20 = pickle.load(open("native_freq_tweets20.p", "rb"))
n21 = pickle.load(open("native_freq_tweets21.p", "rb"))
n22 = pickle.load(open("native_freq_tweets22.p", "rb"))
n23 = pickle.load(open("native_freq_tweets23.p", "rb"))
n24 = pickle.load(open("native_freq_tweets24.p", "rb"))

# %%
native_tweets_by_location = {
    "Santa Coloma de Gramanet" : pd.DataFrame(),
    "Fluvial del Besos" : pd.DataFrame(),
    "Parque Molinet" : pd.DataFrame(),
    "Plaza del Rellotge" : pd.DataFrame(),
    "Rambla San Sebastian" : pd.DataFrame(),
    "Parque Can Zam" : pd.DataFrame(),
    "Instituto Can Peixauet" : pd.DataFrame(),
    "Parque Gran Sol" : pd.DataFrame(),
    "Escuela Tanit" : pd.DataFrame(),
    "Instituto Terra Roja" : pd.DataFrame(),
    "Instituto Gassol" : pd.DataFrame(),
    "CAP Santa Rosa" : pd.DataFrame(),
    "Cinto Verdaguer" : pd.DataFrame(),
    "Mercado del Fondo" : pd.DataFrame(),
    "Nus de la Trinitat" : pd.DataFrame(),
    "Macanet str" : pd.DataFrame(),
    "Iglesia Evangelica" : pd.DataFrame()
}

n_list = [n1,n2,n3,n4,n5,n6,n7,n8,n9,n10,n11,n12,n13,n14,n15,n16,n17,n18,n18_5,n19,n20,n21,n22,n23,n24]
for n in n_list:
    for k,v in native_tweets_by_location.items():
        native_tweets_by_location[k] = v.append(n[k])

# %%
for k,v in native_tweets_by_location.items():
    print(k)
    if (len(set(v["username"])) != 0):
        print("frequency:", len(v), "/ user count:", len(set(v["username"])), "/ freq per user:",len(v) / len(set(v["username"])))
    df_modified = getStats(v)
    for k1, v1 in df_modified.items():
        print(k1)
        if (type(v1) == type(dict())):
            for k2, v2 in v1.items():
                print(k2, v2)
        else: print(v1)
        print()
    print("-----------------------------")
# Out:
# Santa Coloma de Gramanet
# frequency: 7874 / user count: 1088 / freq per user: 7.237132352941177
# size
# 7874
#
# language
# ca 4901 0.6224282448564897
# es 2867 0.3641097282194564
# it 34 0.004318008636017272
# en 22 0.0027940055880111762
# fr 12 0.001524003048006096
# ro 10 0.00127000254000508
# pt 9 0.001143002286004572
# und 8 0.001016002032004064
# fi 6 0.000762001524003048
# in 2 0.000254000508001016
# da 1 0.000127000254000508
# cy 1 0.000127000254000508
# et 1 0.000127000254000508
#
# days
# weekends 1824 0.2316484632969266
# weekdays 6050 0.7683515367030734
#
# -----------------------------
# Fluvial del Besos
# frequency: 1608 / user count: 626 / freq per user: 2.5686900958466454
# size
# 1608
#
# language
# es 1558 0.9689054726368159
# in 34 0.021144278606965175
# ca 7 0.004353233830845771
# lt 5 0.003109452736318408
# pt 2 0.0012437810945273632
# ja 1 0.0006218905472636816
# en 1 0.0006218905472636816
#
# days
# weekends 446 0.277363184079602
# weekdays 1162 0.722636815920398
#
# -----------------------------
# Parque Molinet
# frequency: 741 / user count: 340 / freq per user: 2.179411764705882
# size
# 741
#
# language
# es 525 0.708502024291498
# ca 150 0.20242914979757085
# it 50 0.06747638326585695
# en 4 0.005398110661268556
# und 4 0.005398110661268556
# fi 2 0.002699055330634278
# et 1 0.001349527665317139
# pt 1 0.001349527665317139
# eu 1 0.001349527665317139
# ro 1 0.001349527665317139
# fr 1 0.001349527665317139
# cy 1 0.001349527665317139
#
# days
# weekends 168 0.22672064777327935
# weekdays 573 0.7732793522267206
#
# -----------------------------
# Plaza del Rellotge
# frequency: 43 / user count: 10 / freq per user: 4.3
# size
# 43
#
# language
# ca 43 1.0
#
# days
# weekends 11 0.2558139534883721
# weekdays 32 0.7441860465116279
#
# -----------------------------
# Rambla San Sebastian
# size
# 0
#
# -----------------------------
# Parque Can Zam
# frequency: 356 / user count: 99 / freq per user: 3.595959595959596
# size
# 356
#
# language
# ca 198 0.5561797752808989
# es 144 0.4044943820224719
# ro 6 0.016853932584269662
# en 2 0.0056179775280898875
# it 2 0.0056179775280898875
# pt 2 0.0056179775280898875
# tr 1 0.0028089887640449437
# und 1 0.0028089887640449437
#
# days
# weekends 99 0.27808988764044945
# weekdays 257 0.7219101123595506
#
# -----------------------------
# Instituto Can Peixauet
# frequency: 201 / user count: 45 / freq per user: 4.466666666666667
# size
# 201
#
# language
# ca 158 0.7860696517412935
# es 42 0.208955223880597
# en 1 0.004975124378109453
#
# days
# weekends 32 0.15920398009950248
# weekdays 169 0.8407960199004975
#
# -----------------------------
# Parque Gran Sol
# frequency: 1308 / user count: 588 / freq per user: 2.2244897959183674
# size
# 1308
#
# language
# es 1258 0.9617737003058104
# ca 36 0.027522935779816515
# en 9 0.006880733944954129
# in 2 0.0015290519877675841
# ht 1 0.0007645259938837921
# eu 1 0.0007645259938837921
# tr 1 0.0007645259938837921
#
# days
# weekends 325 0.2484709480122324
# weekdays 983 0.7515290519877675
#
# -----------------------------
# Escuela Tanit
# frequency: 1 / user count: 1 / freq per user: 1.0
# size
# 1
#
# language
# es 1 1.0
#
# days
# weekends 0 0.0
# weekdays 1 1.0
#
# -----------------------------
# Instituto Terra Roja
# frequency: 14 / user count: 6 / freq per user: 2.3333333333333335
# size
# 14
#
# language
# ca 12 0.8571428571428571
# es 2 0.14285714285714285
#
# days
# weekends 1 0.07142857142857142
# weekdays 13 0.9285714285714286
#
# -----------------------------
# Instituto Gassol
# size
# 0
#
# -----------------------------
# CAP Santa Rosa
# size
# 0
#
# -----------------------------
# Cinto Verdaguer
# frequency: 56 / user count: 42 / freq per user: 1.3333333333333333
# size
# 56
#
# language
# ca 33 0.5892857142857143
# es 22 0.39285714285714285
# pt 1 0.017857142857142856
#
# days
# weekends 8 0.14285714285714285
# weekdays 48 0.8571428571428571
#
# -----------------------------
# Mercado del Fondo
# frequency: 29737 / user count: 10558 / freq per user: 2.816537222958894
# size
# 29737
#
# language
# es 29450 0.9903487238120859
# ca 184 0.006187577765073814
# it 84 0.002824763762316306
# en 13 0.00043716582035847597
# pt 2 6.725628005515015e-05
# in 2 6.725628005515015e-05
# et 1 3.3628140027575076e-05
# ht 1 3.3628140027575076e-05
#
# days
# weekends 6059 0.2037529004270774
# weekdays 23678 0.7962470995729226
#
# -----------------------------
# Nus de la Trinitat
# frequency: 531 / user count: 22 / freq per user: 24.136363636363637
# size
# 531
#
# language
# ca 531 1.0
#
# days
# weekends 73 0.1374764595103578
# weekdays 458 0.8625235404896422
#
# -----------------------------
# Macanet str
# size
# 0
#
# -----------------------------
# Iglesia Evangelica
# frequency: 36 / user count: 25 / freq per user: 1.44
# size
# 36
#
# language
# es 35 0.9722222222222222
# ca 1 0.027777777777777776
#
# days
# weekends 10 0.2777777777777778
# weekdays 26 0.7222222222222222
#
# -----------------------------
